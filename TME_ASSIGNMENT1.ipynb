# %% [markdown]
# Import necessary libraries

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Load the MNIST dataset

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# Normalize images

# %%
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),    # Flatten the 2D images into 1D arrays
    layers.Dense(128, activation='relu'),    # First hidden layer
    layers.Dropout(0.2),                     # Dropout layer to prevent overfitting
    layers.Dense(10, activation='softmax')   # Output layer with 10 classes (digits 0-9)
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0008), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train, epochs=20, validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.8500 - loss: 0.5207 - val_accuracy: 0.9550 - val_loss: 0.1507
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9534 - loss: 0.1600 - val_accuracy: 0.9670 - val_loss: 0.1090
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9660 - loss: 0.1139 - val_accuracy: 0.9714 - val_loss: 0.0942
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 22s 7ms/step - accuracy: 0.9727 - loss: 0.0904 - val_accuracy: 0.9747 - val_loss: 0.0816
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9772 - loss: 0.0758 - val_accuracy: 0.9761 - val_loss: 0.0744
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.9801 - loss: 0.0658 - val_accuracy: 0.9783 - val_loss: 0.0743
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 22s 7ms/step - accuracy: 0.9812 - loss: 0.0582 - val_accuracy: 0.9783 - val_loss: 0.0721
# Epoch 8/20
# ...

# %% [markdown]
# Visualize Training History

# %%
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),                     #Changing the dropout
    layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0008), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train, epochs=20, validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.8345 - loss: 0.5563 - val_accuracy: 0.9558 - val_loss: 0.1496
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.9451 - loss: 0.1840 - val_accuracy: 0.9659 - val_loss: 0.1114
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9593 - loss: 0.1355 - val_accuracy: 0.9716 - val_loss: 0.0934
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9676 - loss: 0.1070 - val_accuracy: 0.9723 - val_loss: 0.0848
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9709 - loss: 0.0934 - val_accuracy: 0.9754 - val_loss: 0.0787
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.9745 - loss: 0.0808 - val_accuracy: 0.9764 - val_loss: 0.0745
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9762 - loss: 0.0751 - val_accuracy: 0.9780 - val_loss: 0.0709
# Epoch 8/20
# ...

# %%
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.4),                     #Changing the dropout
    layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0008), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train, epochs=20, validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.8257 - loss: 0.5943 - val_accuracy: 0.9529 - val_loss: 0.1563
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.9401 - loss: 0.1994 - val_accuracy: 0.9646 - val_loss: 0.1152
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9552 - loss: 0.1537 - val_accuracy: 0.9700 - val_loss: 0.0976
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.9591 - loss: 0.1331 - val_accuracy: 0.9735 - val_loss: 0.0904
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 19s 6ms/step - accuracy: 0.9628 - loss: 0.1179 - val_accuracy: 0.9758 - val_loss: 0.0795
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.9669 - loss: 0.1066 - val_accuracy: 0.9766 - val_loss: 0.0770
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9683 - loss: 0.1012 - val_accuracy: 0.9755 - val_loss: 0.0788
# Epoch 8/20
# ...

# %%
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # **Create and Import a Custom Dataset**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
from PIL import Image

# %%
base_folder_path = '/content/drive/MyDrive/CustomMNIST'

custom_images = []
custom_labels = []

# %%
for folder_name in os.listdir(base_folder_path):
    folder_path = os.path.join(base_folder_path, folder_name)
    print(folder_path)
    if os.path.isdir(folder_path):
        for filename in os.listdir(folder_path):
            print('filename', filename)
            # Check for both PNG and JPEG file formats
            if filename.endswith(('.png', '.PNG', '.jpg', '.JPG', '.jpeg', '.JPEG')):
                img_path = os.path.join(folder_path, filename)

                # Open the image and preprocess
                img = Image.open(img_path).convert('L')  # Convert image to grayscale
                img = img.resize((28, 28))  # Resize image to match MNIST dimensions

                # Apply thresholding to make the image binary (black and white)
                threshold = 100
                img = img.point(lambda p: p > threshold and 255)

                # Convert the image to a NumPy array
                img_array = np.array(img)
                custom_images.append(img_array)

                # Use folder name as label
                custom_labels.append(int(folder_name))

# Convert the list of custom images and labels to numpy arrays
custom_images = np.array(custom_images)
custom_labels = np.array(custom_labels)

custom_images = np.expand_dims(custom_images, axis=-1)
print("Shape of custom_images:", custom_images.shape)
# Out:
# /content/drive/MyDrive/CustomMNIST/0
# filename 0_2.png
# filename 0_3.png
# filename 0_1.png
# /content/drive/MyDrive/CustomMNIST/1
# filename 1_2.png
# filename 1_3.png
# filename 1_1.png
# /content/drive/MyDrive/CustomMNIST/3
# filename 3_3.png
# filename 3_2.png
# filename 3_1.png
# /content/drive/MyDrive/CustomMNIST/2
# filename 2_2.png
# filename 2_3.png
# filename 2_1.png
# /content/drive/MyDrive/CustomMNIST/4
# filename 4_2.png
# filename 4_1.png
# filename 4_3.png
# /content/drive/MyDrive/CustomMNIST/5
# filename 5_3.png
# filename 5_1.png
# filename 5_2.png
# /content/drive/MyDrive/CustomMNIST/6
# filename 6_1.png
# filename 6_2.png
# filename 6_3.png
# /content/drive/MyDrive/CustomMNIST/7
# filename 7_1.png
# filename 7_2.png
# filename 7_3.png
# /content/drive/MyDrive/CustomMNIST/8
# filename 8_3.png
# filename 8_1.png
# filename 8_2.png
# /content/drive/MyDrive/CustomMNIST/9
# filename 9_1.png
# filename 9_3.png
# filename 9_2.png
# ...

# %%
predictions = model.predict(custom_images)
predicted_labels = np.argmax(predictions, axis=1)

# Evaluate accuracy by comparing predicted labels to true custom labels
accuracy = np.sum(predicted_labels == custom_labels) / len(custom_labels)
print(f'Custom Dataset Accuracy: {accuracy * 100:.2f}%')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Custom Dataset Accuracy: 13.33%
